# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Sprint1.csv",sep=",")
df
# Out:
#           Type         Product Price  Quantity
# 0        Chips            Lays   R 5      20.0
# 1          NaN        Dorritos   R 6      15.0
# 2          NaN          Frutos   R 7      25.0
# 3          NaN        Nik naks   R 8      30.0
# 4          NaN           Simba   R 9      15.0
# 5        total             NaN   NaN       NaN
# 6   Cooldrinks            Coke  R 12      30.0
# 7          NaN           Fanta  R 11      25.0
# 8          NaN           Score  R 10      40.0
# 9          NaN         Redbull  R 16      20.0
# 10         NaN           Krush  R 22      35.0
# 11         NaN             NaN   NaN       NaN
# 12  Chocolates         Cadbury   R 8      35.0
# 13         NaN              PS  R 12      25.0
# 14         NaN       Lunch bar  R 15      20.0
# 15         NaN         kit kat  R 19      40.0
# 16         NaN         Snicker  R 17      20.0
# 17         NaN             NaN   NaN       NaN
# 18        Pies           steak  R 18      20.0
# ...

# %%
data = np.array(['Type','Products','Quantity'])
s = pd.Series(data)
s
# Out:
# 0        Type
# 1    Products
# 2    Quantity
# dtype: object

# %%
df=pd.read_csv("Sprint1.csv",sep=",")
df.filter(["Quantity", "Type"])
# Out:
#     Quantity        Type
# 0       20.0       Chips
# 1       15.0         NaN
# 2       25.0         NaN
# 3       30.0         NaN
# 4       15.0         NaN
# 5        NaN       total
# 6       30.0  Cooldrinks
# 7       25.0         NaN
# 8       40.0         NaN
# 9       20.0         NaN
# 10      35.0         NaN
# 11       NaN         NaN
# 12      35.0  Chocolates
# 13      25.0         NaN
# 14      20.0         NaN
# 15      40.0         NaN
# 16      20.0         NaN
# 17       NaN         NaN
# 18      20.0        Pies
# 19      16.0         NaN
# 20      12.0         NaN
# 21      18.0         NaN
# 22      15.0         NaN
# 23       NaN         NaN
# 24      25.0       Fruit
# 25      30.0         NaN
# 26      20.0         NaN
# 27      15.0         NaN
# 28      20.0         NaN
# 29      30.0         NaN
# 30       NaN         NaN
# 31      25.0    Cupcakes
# 32      30.0         NaN
# 33      20.0         NaN
# 34      25.0         NaN
# 35      28.0         NaN
# ...

# %%
df.filter(regex ='[dit]')
# Out:
#            Product Price  Quantity
# 0             Lays   R 5      20.0
# 1         Dorritos   R 6      15.0
# 2           Frutos   R 7      25.0
# 3         Nik naks   R 8      30.0
# 4            Simba   R 9      15.0
# 5              NaN   NaN       NaN
# 6             Coke  R 12      30.0
# 7            Fanta  R 11      25.0
# 8            Score  R 10      40.0
# 9          Redbull  R 16      20.0
# 10           Krush  R 22      35.0
# 11             NaN   NaN       NaN
# 12         Cadbury   R 8      35.0
# 13              PS  R 12      25.0
# 14       Lunch bar  R 15      20.0
# 15         kit kat  R 19      40.0
# 16         Snicker  R 17      20.0
# 17             NaN   NaN       NaN
# 18           steak  R 18      20.0
# 19         Chicken  R 22      16.0
# 20          Pepper  R 24      12.0
# 21          burger  R 26      18.0
# 22  cheese griller  R 25      15.0
# 23             NaN   NaN       NaN
# 24           Pears  R 10      25.0
# 25           Apple   R 8      30.0
# ...

# %%
data = [['Lays',5],['Dorritos',6],['Frutos',7],['Nik naks',8],['Simba',9]]
df = pd.DataFrame(data,columns=['Chips','Quantity'])
df
# Out:
#       Chips  Quantity
# 0      Lays         5
# 1  Dorritos         6
# 2    Frutos         7
# 3  Nik naks         8
# 4     Simba         9

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import style

style.use('ggplot')

x = ['Lays','Dorritos','Frutos','Nik naks','Simba']
y = [5,6,7,8,9,]

plt.bar(x, y, align= 'center')

plt.title('chips')
plt.ylabel('price list of chips in Rands')
plt.xlabel('type of chips')

plt.show()
