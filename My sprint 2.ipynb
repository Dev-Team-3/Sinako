# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Sinako@dee1"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %% [markdown]
# import pandas as pd
# import numpy as np
# df=pd.read_csv("Sprint1.csv",sep=",")
# df

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import style

style.use('ggplot')

x = ['Nik naks','Frutos','Simba','Lays','Dorritos']
y = [5,6,7,8,9,]

plt.bar(x, y, align= 'center')

plt.title('chips')
plt.ylabel('price list of chips in Rands')
plt.xlabel('type of chips')

plt.show()

# %%
#scatter plot
x = ['Spinach','Cabbage','Peppers','Carrot','Onion']
y = [10, 5, 20, 10, 5] 
plt.xlabel('Products',fontsize = 18)  
plt.ylabel('Price', fontsize = 18)
plt.scatter(x,y) 
plt.show()

# %%
#plot
x = ['Spinach','Cabbage','Peppers','Carrot','Onion']
y = [10, 5, 20, 10, 5] 
plt.xlabel('Products',fontsize = 18)  
plt.ylabel('Price', fontsize = 18)
plt.plot(x,y) 
plt.show()

# %%
data = {'Spinach': 10, 'Cabbage':5, 'Peppers':20, 'Carrot':10, 'Onion':5}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(15, 3), sharey=True)
axs[0].bar(names, values)

axs[1].scatter(names, values)

axs[2].plot(names, values)

fig.suptitle('categorical Plotting')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
